# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:16, 1.95MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

# vocab_to_int and int_to_vocab are LUTs
# int_words is the text converted to numbers

## Your code here
threshold = 1e-5
word_counts = Counter(int_words) # get count of words
total_words = len(int_words) # how many words do we got
frequency = {word: count / total_words for word, count in word_counts.items()} # create dictionary / LUT of frequency for all words
p_prob = {word: 1- np.sqrt(threshold/frequency[word]) for word, freq in frequency.items()} # convert frequency to probability
train_words = [word for word in int_words if p_prob[word] < random.random()] # copy word if probability criteria is met

#train_words = # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, window_size + 1) # generate the random number to generate the random boundaries
    idx_low = idx - R if (idx-R>0) else 0 # Lower index (take care of 0)
    idx_high = idx + R # Upper index
    output = set(words[idx_low:idx] + words[idx+1:idx_high+1]) # Set to remove possible duplicates
    return list(output)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1, 1 )) # Why uniform?
    embed = tf.nn.embedding_lookup(embedding, inputs) # inputs = one-hot encoding to get only the corresponding row

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.3)) # similar as previous project
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    # input is only the selelcted row, for speed
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.2982 0.1252 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.2855 0.1189 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 7.1505 0.1201 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 7.2011 0.1187 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 7.0684 0.1191 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 7.0850 0.1193 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 7.0756 0.1193 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 7.0584 0.1178 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 6.9736 0.1182 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 6.9177 0.1162 sec/batch
# Nearest to or: fixes, warburg, kampen, cancers, receiver, martov, indeed, justifies,
# Nearest to th: slugger, batsford, jiangxi, conduction, experiment, tigrinya, vivace, istanbul,
# Nearest to all: improving, standardize, eccentrics, glycemic, pickets, tito, tdma, faceted,
# Nearest to d: ims, arias, stump, tribal, immorality, allowance, underwent, rsha,
# Nearest to first: clemens, statuary, hitchens, blessings, daimyo, passers, geometry, soldiery,
# Nearest to over: nucleosome, humber, improvement, andrey, walking, classifies, breatharian, grands,
# Nearest to war: slavic, accompaniments, aleksey, lublin, goodtimes, wish, suvorov, soaked,
# Nearest to to: complement, barbadian, laurence, yung, dich, tricking, beautifully, leland,
# Nearest to proposed: vv, pci, propylaea, minute, sequencing, esoteric, avc, foxe,
# Nearest to troops: bail, rohrabacher, iterative, mariculture, ventspils, swaraj, expired, vdots,
# Nearest to smith: dissemination, annette, culturally, susskind, stylists, dits, vogt, gosse,
# Nearest to quite: rieur, turkish, abbotsford, sagan, windsurfing, cultic, galvanic, dare,
# Nearest to woman: reinhardt, ree, awt, andrei, enfant, caballero, disciplining, proportionately,
# Nearest to nobel: meuse, disposes, hauer, apap, enacts, semitism, perceive, booksellers,
# Nearest to governor: gorillaz, crucifixion, annular, bystander, seagate, zonker, watering, kerala,
# Nearest to construction: sensibilities, chipped, nickel, allein, piotr, teaspoons, iterations, thumbnail,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 6.9882 0.1162 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 6.8720 0.1160 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 6.8385 0.1185 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 6.7944 0.1154 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 6.7546 0.1143 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 6.7564 0.1107 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 6.6794 0.1129 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 6.6487 0.1164 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 6.6202 0.1172 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 6.6231 0.1143 sec/batch
# Nearest to or: fixes, receiver, warburg, cancers, kampen, costanza, indeed, martov,
# Nearest to th: slugger, batsford, tigrinya, experiment, vivace, jiangxi, conduction, helmets,
# Nearest to all: improving, standardize, pickets, eccentrics, faceted, tdma, barrack, penal,
# Nearest to d: ims, arias, tribal, stump, allowance, underwent, multiverses, immorality,
# Nearest to first: clemens, statuary, passers, daimyo, hitchens, london, stole, blessings,
# Nearest to over: nucleosome, improvement, humber, classifies, walking, andrey, grands, credit,
# Nearest to war: slavic, accompaniments, aleksey, lublin, goodtimes, suvorov, wish, regulator,
# Nearest to to: complement, barbadian, yung, laurence, leland, beautifully, bipeds, suspected,
# Nearest to proposed: vv, pci, propylaea, minute, esoteric, avc, foxe, prop,
# Nearest to troops: bail, rohrabacher, cash, swaraj, iterative, ventspils, mariculture, vdots,
# Nearest to smith: dissemination, annette, stylists, vogt, culturally, susskind, dits, gosse,
# Nearest to quite: rieur, turkish, abbotsford, sagan, windsurfing, cultic, galvanic, pacification,
# Nearest to woman: reinhardt, awt, enfant, ree, andrei, caballero, exclude, proportionately,
# Nearest to nobel: meuse, disposes, hauer, apap, booksellers, semitism, enacts, perceive,
# Nearest to governor: gorillaz, crucifixion, bystander, annular, seagate, watering, profitability, kerala,
# Nearest to construction: sensibilities, nickel, chipped, allein, piotr, iterations, moderne, teaspoons,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 6.5288 0.1191 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 6.5269 0.1174 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 6.4838 0.1165 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 6.4511 0.1167 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 6.3454 0.1158 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 6.3881 0.1165 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 6.3141 0.1170 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 6.2127 0.1163 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 6.2166 0.1174 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 6.1728 0.1150 sec/batch
# Nearest to or: fixes, indeed, receiver, costanza, justifies, warburg, novelists, kampen,
# Nearest to th: batsford, helmets, slugger, istanbul, experiment, foregoing, material, fletcher,
# Nearest to all: improving, risk, pickets, with, barrack, faceted, standardize, comparison,
# Nearest to d: tribal, ims, allowance, stump, arias, underwent, icon, ely,
# Nearest to first: clemens, statuary, passers, geometry, network, london, led, skull,
# Nearest to over: improvement, nucleosome, classifies, credit, humber, walking, rear, andrey,
# Nearest to war: slavic, accompaniments, sellers, benign, goodtimes, wish, savior, lublin,
# Nearest to to: in, by, complement, laurence, barbadian, beautifully, yung, is,
# Nearest to proposed: vv, minute, esoteric, propylaea, pci, prop, foxe, rivest,
# Nearest to troops: bail, rohrabacher, cash, ventriloquist, dkk, saf, swaraj, ioan,
# Nearest to smith: dissemination, culturally, annette, realistic, susskind, stylists, sexuality, datum,
# Nearest to quite: rieur, turkish, galvanic, sagan, abbotsford, automatically, cultic, pacification,
# Nearest to woman: reinhardt, awt, exclude, enfant, ree, andrei, arrived, caballero,
# Nearest to nobel: meuse, hauer, booksellers, disposes, semitism, higher, perceive, shimmering,
# Nearest to governor: gorillaz, crucifixion, watering, bystander, annular, seagate, participating, oddly,
# Nearest to construction: sensibilities, nickel, chipped, allein, piotr, iterations, pi, assets,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 6.1383 0.1178 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 6.1107 0.1166 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 6.0292 0.1145 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 5.9667 0.1167 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 6.0163 0.1159 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 5.9287 0.1170 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 5.8965 0.1168 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 5.8499 0.1172 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 5.8329 0.1148 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 5.7685 0.1133 sec/batch
# Nearest to or: indeed, the, fixes, receiver, up, and, through, justifies,
# Nearest to th: batsford, helmets, slugger, fletcher, istanbul, revealed, manages, petrels,
# Nearest to all: improving, with, risk, zero, not, suggest, segregation, barrack,
# Nearest to d: tribal, chemist, icon, allowance, underwent, arias, ims, multiverses,
# Nearest to first: london, led, this, a, skull, statuary, slow, lawyers,
# Nearest to over: improvement, nucleosome, walking, according, classifies, credit, four, jewish,
# Nearest to war: slavic, sellers, wish, accompaniments, benign, savior, goodtimes, regulator,
# Nearest to to: in, by, is, the, on, also, complement, s,
# Nearest to proposed: minute, vv, awarded, esoteric, propylaea, combinations, pci, united,
# Nearest to troops: bail, practical, rohrabacher, autocratic, cash, mortars, expired, deltas,
# Nearest to smith: dissemination, culturally, developed, realistic, not, sexuality, susskind, stylists,
# Nearest to quite: turkish, automatically, rieur, galvanic, sagan, pacification, cultic, dare,
# Nearest to woman: exclude, arrived, awt, reinhardt, andrei, renowned, anymore, ree,
# Nearest to nobel: booksellers, meuse, higher, perceive, hauer, disposes, mon, documents,
# Nearest to governor: gorillaz, crucifixion, participating, efforts, kerala, oddly, watering, scandals,
# Nearest to construction: sensibilities, nickel, chipped, assets, pi, allein, eleven, iterations,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 5.7388 0.1153 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 5.7078 0.1153 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 5.6541 0.1090 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 5.6738 0.1140 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 5.6338 0.1138 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 5.5687 0.1158 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 5.5367 0.0846 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 5.4899 0.1164 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 5.3889 0.1177 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 5.3996 0.1148 sec/batch
# Nearest to or: the, and, fixes, indeed, receiver, up, a, this,
# Nearest to th: in, batsford, helmets, two, news, fletcher, happen, revealed,
# Nearest to all: with, it, and, not, improving, as, zero, have,
# Nearest to d: chemist, american, icon, writer, tribal, underwent, allowance, five,
# Nearest to first: a, s, this, slow, london, led, five, the,
# Nearest to over: improvement, for, walking, by, classifies, four, nucleosome, credit,
# Nearest to war: slavic, wish, sellers, accompaniments, benign, aleksey, savior, to,
# Nearest to to: in, the, by, is, and, on, of, a,
# Nearest to proposed: minute, vv, combinations, awarded, academic, the, esoteric, prop,
# Nearest to troops: bail, practical, expired, autocratic, medical, cash, rohrabacher, tasman,
# Nearest to smith: culturally, dissemination, not, realistic, developed, susskind, others, sexuality,
# Nearest to quite: turkish, automatically, pacification, galvanic, dare, rieur, were, figurative,
# Nearest to woman: arrived, exclude, andrei, anymore, renowned, rounding, awt, reinhardt,
# Nearest to nobel: booksellers, perceive, meuse, mon, higher, hauer, documents, farnese,
# Nearest to governor: gorillaz, efforts, crucifixion, participating, scandals, gracie, oddly, kerala,
# Nearest to construction: nickel, sensibilities, chipped, assets, iterations, eleven, facilitates, pi,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 5.3866 0.1158 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 5.3233 0.1169 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 5.3115 0.1153 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 5.3412 0.1174 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 5.2798 0.1154 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 5.2557 0.1127 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 5.2153 0.1167 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 5.1551 0.1169 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 5.1842 0.1152 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 5.1648 0.1157 sec/batch
# Nearest to or: the, and, a, this, it, is, to, in,
# Nearest to th: in, two, batsford, helmets, fletcher, istanbul, news, happen,
# Nearest to all: with, it, and, as, not, have, of, a,
# Nearest to d: chemist, american, icon, writer, five, one, tribal, underwent,
# Nearest to first: a, s, the, in, five, this, to, for,
# Nearest to over: for, improvement, by, of, to, walking, first, and,
# Nearest to war: slavic, wish, the, sellers, after, savior, during, consciousness,
# Nearest to to: in, the, and, by, a, of, is, on,
# Nearest to proposed: minute, vv, combinations, academic, awarded, the, into, pci,
# Nearest to troops: bail, practical, expired, autocratic, cash, enrich, tasman, deltas,
# Nearest to smith: culturally, dissemination, not, others, realistic, developed, susskind, doctrines,
# Nearest to quite: turkish, were, automatically, figurative, dare, black, after, considered,
# Nearest to woman: arrived, anymore, exclude, chairman, rounding, andrei, firms, reinhardt,
# Nearest to nobel: booksellers, mon, perceive, meuse, documents, rescued, hauer, succession,
# Nearest to governor: efforts, scandals, participating, gorillaz, crucifixion, gracie, oddly, appointing,
# Nearest to construction: nickel, sensibilities, chipped, assets, pi, iterations, facilitates, some,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 5.1677 0.1148 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 5.1185 0.1164 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 5.1357 0.1164 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 5.1293 0.1156 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 5.1112 0.1172 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 5.1169 0.1156 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 5.0460 0.1140 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 5.0456 0.1146 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 5.0430 0.1103 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 5.0429 0.1097 sec/batch
# Nearest to or: the, this, is, and, to, as, a, it,
# Nearest to th: one, in, two, of, batsford, the, was, under,
# Nearest to all: not, with, it, of, as, and, have, a,
# Nearest to d: american, one, chemist, five, writer, eight, icon, seven,
# Nearest to first: in, a, the, s, to, was, for, of,
# Nearest to over: for, by, to, improvement, first, of, and, it,
# Nearest to war: after, slavic, was, during, the, were, wish, became,
# Nearest to to: the, in, and, a, of, by, is, an,
# Nearest to proposed: minute, combinations, vv, the, colonized, academic, awarded, prop,
# Nearest to troops: bail, expired, practical, rohrabacher, enrich, mortars, autocratic, deltas,
# Nearest to smith: dissemination, culturally, others, english, stylists, realistic, annette, susskind,
# Nearest to quite: turkish, were, automatically, figurative, productivity, considered, dare, galvanic,
# Nearest to woman: arrived, exclude, anymore, say, denounced, andrei, king, rounding,
# Nearest to nobel: booksellers, controllable, touchdown, deaths, rescued, succession, italian, farnese,
# Nearest to governor: efforts, participating, scandals, gracie, gorillaz, crucifixion, appointing, marks,
# Nearest to construction: nickel, sensibilities, for, pi, some, iterations, chipped, are,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 5.0234 0.1143 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.9689 0.1154 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.9417 0.1140 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.9996 0.1146 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 5.0230 0.1133 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.9661 0.1168 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.9396 0.1160 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.9393 0.1161 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.8988 0.1113 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.9052 0.1163 sec/batch
# Nearest to or: are, it, is, a, this, the, to, as,
# Nearest to th: was, the, one, in, of, became, two, under,
# Nearest to all: with, as, it, not, have, a, and, of,
# Nearest to d: one, eight, american, five, seven, chemist, four, writer,
# Nearest to first: in, the, s, to, by, a, from, was,
# Nearest to over: for, by, and, to, in, of, first, the,
# Nearest to war: was, after, were, during, became, united, the, army,
# Nearest to to: the, in, and, a, of, by, as, it,
# Nearest to proposed: minute, the, vv, combinations, academic, colonized, precursor, prop,
# Nearest to troops: bail, expired, was, lublin, to, of, deltas, autocratic,
# Nearest to smith: others, dissemination, culturally, english, sexuality, stylists, susskind, annette,
# Nearest to quite: this, as, turkish, with, figurative, considered, were, a,
# Nearest to woman: arrived, anymore, s, exclude, andrei, denounced, king, rounding,
# Nearest to nobel: booksellers, deaths, laureate, eight, nine, touchdown, controllable, italian,
# Nearest to governor: efforts, participating, appointing, gracie, states, crucifixion, president, scandals,
# Nearest to construction: nickel, for, sensibilities, iterations, are, some, sufficient, the,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.8788 0.1179 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.9069 0.1153 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.8953 0.1159 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.9207 0.1167 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.9091 0.1166 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.8058 0.1156 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.8319 0.1149 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.8419 0.1150 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.7738 0.1167 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.8170 0.1149 sec/batch
# Nearest to or: is, are, this, can, not, it, be, a,
# Nearest to th: the, of, in, was, one, became, two, first,
# Nearest to all: it, with, not, this, a, as, for, which,
# Nearest to d: one, eight, seven, nine, american, five, two, four,
# Nearest to first: s, was, in, the, by, for, on, to,
# Nearest to over: for, by, its, and, in, first, the, to,
# Nearest to war: during, was, became, were, after, united, the, army,
# Nearest to to: the, in, and, by, a, of, as, it,
# Nearest to proposed: vv, combinations, precursor, the, minute, academic, although, colonized,
# Nearest to troops: was, war, of, lublin, to, bail, expired, he,
# Nearest to smith: english, others, dissemination, stylists, culturally, susskind, annette, constables,
# Nearest to quite: this, as, a, that, considered, with, can, such,
# Nearest to woman: s, arrived, and, anymore, andrei, exclude, of, i,
# Nearest to nobel: nine, eight, one, laureate, d, b, six, american,
# Nearest to governor: efforts, president, states, gracie, appointed, established, united, participating,
# Nearest to construction: nickel, iterations, yat, sensibilities, of, are, small, assets,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.8361 0.1174 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.7941 0.1160 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.8159 0.0544 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.7155 0.1183 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.7217 0.1166 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.7171 0.1145 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.6834 0.1111 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.6990 0.1108 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.6734 0.1170 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.6426 0.1163 sec/batch
# Nearest to or: are, can, is, be, this, it, not, to,
# Nearest to th: century, one, the, in, was, became, five, of,
# Nearest to all: it, this, is, with, for, not, a, that,
# Nearest to d: one, nine, seven, eight, american, five, four, b,
# Nearest to first: s, was, on, by, one, nine, in, the,
# Nearest to over: its, the, for, of, by, and, to, in,
# Nearest to war: was, during, after, became, army, were, united, the,
# Nearest to to: a, and, the, it, by, that, in, from,
# Nearest to proposed: combinations, although, vv, but, colonized, minute, academic, prop,
# Nearest to troops: war, was, lublin, independence, military, bail, and, armies,
# Nearest to smith: english, dissemination, others, stylists, annette, culturally, susskind, cooke,
# Nearest to quite: this, as, with, considered, a, that, it, is,
# Nearest to woman: i, anymore, s, arrived, bofh, andrei, biography, king,
# Nearest to nobel: laureate, nine, eight, d, prize, one, b, american,
# Nearest to governor: president, states, appointed, efforts, presidential, united, gracie, appointing,
# Nearest to construction: nickel, the, iterations, assets, yat, contributes, of, small,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.6720 0.1157 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.6645 0.1177 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.6691 0.1150 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.5420 0.1154 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.6309 0.1175 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.6100 0.1151 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.6252 0.1158 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.5723 0.1150 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.5626 0.1159 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.5901 0.1121 sec/batch
# Nearest to or: are, is, be, can, this, as, to, not,
# Nearest to th: century, one, first, rd, became, was, the, eight,
# Nearest to all: a, this, is, not, it, that, as, for,
# Nearest to d: one, seven, eight, nine, five, american, b, six,
# Nearest to first: s, was, on, after, the, by, one, in,
# Nearest to over: and, under, for, its, at, to, the, by,
# Nearest to war: during, army, was, became, after, were, led, forces,
# Nearest to to: a, which, the, and, this, as, by, an,
# Nearest to proposed: of, vv, combinations, into, but, gbit, precursor, formal,
# Nearest to troops: war, was, were, military, independence, lublin, battle, armies,
# Nearest to smith: english, cooke, dissemination, susskind, stylists, others, annette, lyceum,
# Nearest to quite: this, as, can, them, with, to, similar, that,
# Nearest to woman: bofh, anymore, biography, exclude, s, served, chalcedon, andrei,
# Nearest to nobel: laureate, prize, eight, nine, d, american, six, seven,
# Nearest to governor: president, appointed, states, presidential, gracie, appointing, united, minister,
# Nearest to construction: nickel, products, of, the, largest, assets, contributes, industry,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.5893 0.1169 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.5940 0.1141 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.5482 0.1152 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.5239 0.1141 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.5882 0.1168 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.5609 0.1161 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.5599 0.1155 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.5434 0.1152 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.4488 0.1161 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.5051 0.1171 sec/batch
# Nearest to or: are, can, be, is, to, more, as, which,
# Nearest to th: century, rd, of, by, one, first, was, became,
# Nearest to all: for, not, it, is, a, this, with, there,
# Nearest to d: one, b, seven, eight, nine, american, six, four,
# Nearest to first: on, by, s, the, a, was, with, in,
# Nearest to over: and, the, for, its, to, with, under, zero,
# Nearest to war: army, during, were, after, was, forces, troops, became,
# Nearest to to: and, it, not, the, by, their, a, that,
# Nearest to proposed: vv, combinations, of, formal, academic, trapping, precursor, instance,
# Nearest to troops: war, independence, was, military, battle, rebellion, were, forces,
# Nearest to smith: cooke, english, dissemination, stylists, susskind, annette, physiology, lyceum,
# Nearest to quite: this, can, as, similar, them, considered, there, very,
# Nearest to woman: bofh, his, s, anymore, father, biography, who, life,
# Nearest to nobel: laureate, prize, eight, nine, b, american, d, one,
# Nearest to governor: president, appointed, states, presidential, minister, former, appointing, united,
# Nearest to construction: nickel, products, largest, contributes, and, small, assets, iterations,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.5409 0.1178 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.5237 0.1168 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.5343 0.1159 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.5441 0.1081 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.5027 0.1122 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.4327 0.1150 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.4776 0.1170 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.4655 0.1169 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.4981 0.1145 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.5024 0.1128 sec/batch
# Nearest to or: are, be, not, more, have, some, can, is,
# Nearest to th: century, of, in, the, from, rd, one, by,
# Nearest to all: a, for, not, this, it, only, the, is,
# Nearest to d: one, eight, b, seven, nine, five, two, six,
# Nearest to first: on, s, was, by, a, in, the, after,
# Nearest to over: under, the, to, and, its, for, in, years,
# Nearest to war: during, army, was, were, forces, led, troops, after,
# Nearest to to: the, was, as, were, that, in, by, their,
# Nearest to proposed: of, state, academic, an, general, formal, although, the,
# Nearest to troops: war, forces, during, military, were, led, battle, army,
# Nearest to smith: english, cooke, physiology, dissemination, susskind, annette, stylists, american,
# Nearest to quite: can, similar, very, typically, some, this, as, are,
# Nearest to woman: s, life, at, i, bofh, anymore, family, his,
# Nearest to nobel: eight, one, nine, laureate, prize, d, american, four,
# Nearest to governor: president, appointed, states, united, former, presidential, established, minister,
# Nearest to construction: largest, small, industry, products, nickel, approximately, built, transport,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.5907 0.1184 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.3839 0.1171 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.4438 0.1166 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.4386 0.1151 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.3460 0.1136 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.4396 0.1164 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.4643 0.1157 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.4198 0.1164 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.4211 0.0225 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.4001 0.1176 sec/batch
# Nearest to or: can, are, be, is, as, more, such, not,
# Nearest to th: century, rd, of, the, central, nd, in, day,
# Nearest to all: not, in, a, is, only, this, it, there,
# Nearest to d: one, b, eight, seven, nine, american, three, two,
# Nearest to first: on, s, was, the, by, a, one, with,
# Nearest to over: under, years, the, s, at, in, zero, total,
# Nearest to war: during, army, forces, were, was, after, troops, led,
# Nearest to to: that, it, but, the, an, be, a, not,
# Nearest to proposed: an, of, formal, combinations, its, general, academic, the,
# Nearest to troops: war, forces, military, during, army, were, armies, battle,
# Nearest to smith: english, annette, physiology, susskind, nobel, fred, freddie, cooke,
# Nearest to quite: as, can, similar, very, this, typically, it, them,
# Nearest to woman: life, i, birth, children, living, years, s, women,
# Nearest to nobel: prize, laureate, nine, american, d, eight, one, seven,
# Nearest to governor: president, appointed, states, presidential, former, minister, united, appointing,
# Nearest to construction: largest, industry, products, transport, industries, city, built, contributes,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.3849 0.1143 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.3917 0.1153 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.3472 0.1138 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.3624 0.1161 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.3467 0.1150 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.3049 0.1162 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.3504 0.1153 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.3433 0.1156 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.3782 0.1174 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.2663 0.1131 sec/batch
# Nearest to or: are, be, can, other, is, some, such, it,
# Nearest to th: century, rd, in, the, east, nd, of, period,
# Nearest to all: a, is, are, only, this, it, an, then,
# Nearest to d: b, one, eight, seven, nine, six, writer, american,
# Nearest to first: on, s, the, after, was, a, by, with,
# Nearest to over: under, years, there, s, zero, for, by, to,
# Nearest to war: army, during, forces, were, troops, battle, after, led,
# Nearest to to: as, but, a, it, that, the, an, and,
# Nearest to proposed: of, general, this, by, an, formal, combinations, which,
# Nearest to troops: war, forces, army, were, military, armies, during, battle,
# Nearest to smith: english, annette, susskind, cooke, lyceum, stylists, stories, freddie,
# Nearest to quite: as, very, seems, there, similar, with, from, more,
# Nearest to woman: birth, life, children, father, mother, my, her, she,
# Nearest to nobel: prize, laureate, d, recipient, american, nine, scientist, eight,
# Nearest to governor: president, appointed, states, presidential, minister, former, appointing, united,
# Nearest to construction: largest, industry, transport, built, city, small, products, area,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.2684 0.1121 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.2721 0.1102 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.2817 0.1165 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.2843 0.1178 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.2860 0.1151 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.2768 0.1173 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.3005 0.1160 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.3243 0.1131 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.2847 0.1158 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.2665 0.1155 sec/batch
# Nearest to or: be, can, is, are, more, may, such, other,
# Nearest to th: century, rd, nd, central, period, east, west, st,
# Nearest to all: the, there, a, only, not, is, this, are,
# Nearest to d: b, one, eight, seven, nine, writer, six, four,
# Nearest to first: was, after, on, s, the, by, later, a,
# Nearest to over: under, years, there, total, and, the, zero, all,
# Nearest to war: army, forces, troops, during, battle, led, were, union,
# Nearest to to: this, that, it, the, not, be, as, which,
# Nearest to proposed: of, an, this, which, by, general, state, both,
# Nearest to troops: war, forces, army, battle, military, armies, invasion, allied,
# Nearest to smith: annette, cooke, john, susskind, author, american, economist, stylists,
# Nearest to quite: very, similar, seems, as, into, typically, simply, it,
# Nearest to woman: children, birth, mother, she, her, women, married, father,
# Nearest to nobel: prize, laureate, d, nine, american, recipient, eight, one,
# Nearest to governor: president, appointed, states, presidential, former, appointing, legislature, minister,
# Nearest to construction: largest, built, transport, industry, city, products, area, industries,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.3112 0.1183 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.3281 0.1164 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.2893 0.1144 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.2569 0.1170 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.2547 0.1147 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.2749 0.1176 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.2695 0.1165 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.2560 0.1170 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.2843 0.1145 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.3005 0.1156 sec/batch
# Nearest to or: are, be, more, usually, other, can, is, some,
# Nearest to th: century, period, rd, nd, centuries, of, central, the,
# Nearest to all: there, only, not, every, the, that, given, it,
# Nearest to d: b, one, seven, nine, eight, writer, j, american,
# Nearest to first: on, the, was, after, s, time, by, in,
# Nearest to over: under, zero, the, years, total, five, for, three,
# Nearest to war: army, forces, during, were, troops, led, battle, invasion,
# Nearest to to: the, they, but, in, that, this, their, not,
# Nearest to proposed: state, general, an, of, government, membership, this, academic,
# Nearest to troops: war, forces, army, were, military, armies, battle, soldiers,
# Nearest to smith: cooke, annette, economist, susskind, john, physiology, lyceum, director,
# Nearest to quite: more, it, similar, some, very, can, as, typically,
# Nearest to woman: children, mother, birth, married, women, her, life, living,
# Nearest to nobel: prize, laureate, d, recipient, scientist, b, physicist, american,
# Nearest to governor: president, appointed, states, former, appointing, chief, presidential, minister,
# Nearest to construction: built, largest, city, transport, area, capital, industry, unit,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.2476 0.1159 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.1864 0.1164 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.2156 0.1155 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.2542 0.1168 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.2568 0.1157 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.3201 0.1109 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.3419 0.1170 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.2184 0.1125 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.2197 0.1124 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.2451 0.1153 sec/batch
# Nearest to or: are, be, usually, can, not, is, such, some,
# Nearest to th: century, rd, nd, centuries, central, period, east, three,
# Nearest to all: every, only, the, this, there, not, it, a,
# Nearest to d: b, one, eight, seven, writer, american, nine, laureate,
# Nearest to first: on, the, was, after, s, time, by, in,
# Nearest to over: under, years, in, zero, the, total, five, four,
# Nearest to war: army, during, forces, troops, soviet, were, invasion, allied,
# Nearest to to: that, it, would, not, be, this, the, but,
# Nearest to proposed: general, state, an, of, membership, terms, precursor, independent,
# Nearest to troops: war, forces, army, allied, military, armies, battle, during,
# Nearest to smith: economist, author, american, english, annette, cooke, physiology, john,
# Nearest to quite: very, can, similar, some, typically, more, seems, as,
# Nearest to woman: children, mother, birth, her, married, women, she, life,
# Nearest to nobel: prize, laureate, d, recipient, scientist, american, physiology, nine,
# Nearest to governor: president, appointed, states, former, presidential, chief, vice, general,
# Nearest to construction: built, largest, city, capital, transport, area, in, town,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.1412 0.1168 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.2087 0.1140 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.2347 0.1167 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.2014 0.1166 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.2652 0.1167 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.2163 0.1066 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.1922 0.1131 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.2040 0.1147 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.1750 0.1105 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.1621 0.1116 sec/batch
# Nearest to or: are, can, other, such, some, be, is, usually,
# Nearest to th: century, rd, nd, central, east, st, centuries, west,
# Nearest to all: the, every, in, only, there, a, this, given,
# Nearest to d: b, one, eight, nine, seven, writer, american, five,
# Nearest to first: on, the, in, was, a, second, after, s,
# Nearest to over: under, years, total, there, in, to, only, for,
# Nearest to war: army, forces, during, troops, battle, invasion, soviet, fought,
# Nearest to to: that, was, when, be, not, in, and, but,
# Nearest to proposed: general, state, terms, an, within, responsible, precursor, government,
# Nearest to troops: war, army, forces, battle, armies, military, allied, soldiers,
# Nearest to smith: economist, annette, cooke, author, susskind, realistic, director, lyceum,
# Nearest to quite: very, similar, can, like, much, some, typically, seems,
# Nearest to woman: children, birth, mother, her, women, she, married, father,
# Nearest to nobel: prize, laureate, recipient, d, scientist, physiology, nine, physicist,
# Nearest to governor: president, appointed, former, states, presidential, appointing, general, vice,
# Nearest to construction: built, largest, city, transport, industry, industries, building, industrial,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.1633 0.1092 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.1132 0.1134 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.1584 0.1114 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.1584 0.1102 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.1784 0.1009 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.1297 0.1100 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 4.0638 0.1126 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.1024 0.1164 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.1055 0.1136 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.1169 0.1161 sec/batch
# Nearest to or: are, can, is, be, other, usually, some, such,
# Nearest to th: century, rd, nd, central, east, centuries, period, st,
# Nearest to all: a, the, every, only, there, in, this, with,
# Nearest to d: b, one, eight, writer, seven, nine, l, six,
# Nearest to first: the, in, on, after, second, a, was, with,
# Nearest to over: under, years, total, zero, four, one, there, three,
# Nearest to war: army, forces, during, troops, soviet, battle, invasion, led,
# Nearest to to: an, a, that, it, but, be, not, this,
# Nearest to proposed: general, state, of, responsible, model, precursor, principle, terms,
# Nearest to troops: war, forces, army, armies, battle, soldiers, allied, enemy,
# Nearest to smith: economist, author, cooke, annette, susskind, lyceum, john, american,
# Nearest to quite: very, similar, much, some, as, more, example, typically,
# Nearest to woman: children, mother, birth, married, women, her, born, female,
# Nearest to nobel: prize, laureate, recipient, physiology, scientist, physicist, d, economist,
# Nearest to governor: appointed, president, states, former, appointing, presidential, legislature, general,
# Nearest to construction: built, city, building, transport, largest, industries, industrial, industry,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.1281 0.1166 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.1366 0.1156 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.1084 0.1154 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.1607 0.1155 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.1762 0.1160 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.0765 0.1078 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.1155 0.1153 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.1111 0.1139 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.1177 0.1155 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.1274 0.1098 sec/batch
# Nearest to or: is, are, be, can, usually, not, as, other,
# Nearest to th: century, rd, nd, central, st, centuries, period, lost,
# Nearest to all: only, every, this, there, the, a, is, for,
# Nearest to d: b, one, writer, nine, eight, seven, american, physicist,
# Nearest to first: the, was, by, in, on, after, later, third,
# Nearest to over: years, under, total, all, there, three, zero, for,
# Nearest to war: army, forces, troops, during, soviet, battle, led, invasion,
# Nearest to to: that, the, this, not, be, a, as, it,
# Nearest to proposed: state, general, responsible, theoretical, principle, model, theories, within,
# Nearest to troops: war, forces, army, armies, battle, soldiers, allied, allies,
# Nearest to smith: cooke, economist, author, annette, american, bill, susskind, john,
# Nearest to quite: very, much, similar, well, more, seems, typically, simply,
# Nearest to woman: children, mother, married, birth, women, her, she, father,
# Nearest to nobel: prize, laureate, recipient, d, scientist, physicist, nine, physiology,
# Nearest to governor: president, appointed, former, states, presidential, general, appointing, legislature,
# Nearest to construction: built, building, city, transport, capital, industries, largest, industrial,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.1090 0.1182 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0842 0.1170 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0842 0.1147 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.1486 0.1161 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.1237 0.1164 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.1112 0.1109 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0908 0.1141 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.0865 0.1140 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0494 0.1167 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.1449 0.1151 sec/batch
# Nearest to or: are, can, usually, is, other, not, such, be,
# Nearest to th: century, rd, nd, centuries, central, period, lost, st,
# Nearest to all: only, there, it, are, this, is, called, given,
# Nearest to d: b, one, writer, eight, laureate, nine, american, composer,
# Nearest to first: was, the, by, time, in, on, of, after,
# Nearest to over: under, total, years, four, zero, three, in, two,
# Nearest to war: army, during, forces, troops, soviet, invasion, allied, battle,
# Nearest to to: the, in, that, was, not, of, with, they,
# Nearest to proposed: state, general, responsible, government, membership, of, principle, opposition,
# Nearest to troops: war, forces, army, armies, battle, soldiers, allied, attack,
# Nearest to smith: economist, cooke, author, american, annette, john, susskind, alan,
# Nearest to quite: very, more, some, simply, seems, well, similar, much,
# Nearest to woman: children, birth, mother, women, her, female, married, born,
# Nearest to nobel: prize, laureate, recipient, scientist, physiology, d, american, physicist,
# Nearest to governor: appointed, president, former, states, general, advice, presidential, appointing,
# Nearest to construction: built, building, largest, city, capital, industries, transport, area,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.0912 0.1175 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.2008 0.1151 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.1453 0.1147 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.1359 0.1151 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 4.0179 0.1165 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 4.0272 0.1162 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0898 0.1148 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 4.0197 0.1163 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.1028 0.1155 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 4.0968 0.1158 sec/batch
# Nearest to or: are, can, is, such, as, usually, sometimes, be,
# Nearest to th: rd, nd, century, central, st, east, centuries, lost,
# Nearest to all: is, only, called, are, the, there, every, this,
# Nearest to d: b, one, writer, eight, nine, seven, american, composer,
# Nearest to first: was, the, on, with, in, time, for, record,
# Nearest to over: years, total, under, zero, three, four, five, two,
# Nearest to war: forces, army, during, troops, battle, allied, attack, invasion,
# Nearest to to: that, an, in, a, with, not, it, the,
# Nearest to proposed: general, responsible, state, membership, government, an, principle, terms,
# Nearest to troops: forces, war, army, soldiers, armies, battle, allied, attack,
# Nearest to smith: economist, author, susskind, alan, american, annette, bill, cooke,
# Nearest to quite: very, well, more, much, simply, as, similar, many,
# Nearest to woman: children, birth, mother, her, women, she, married, female,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, american, nine, scientist,
# Nearest to governor: appointed, president, former, general, presidential, chief, states, advice,
# Nearest to construction: city, building, built, largest, capital, industries, industrial, constructed,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 4.1037 0.1165 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 4.1018 0.0758 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 4.0526 0.1085 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 4.0279 0.1146 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 4.0543 0.1162 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 4.0448 0.1169 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 4.0618 0.1169 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.9979 0.1161 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 4.0411 0.1123 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 4.0813 0.1152 sec/batch
# Nearest to or: is, can, are, be, usually, other, such, sometimes,
# Nearest to th: rd, century, nd, east, st, central, centuries, lost,
# Nearest to all: a, the, called, every, only, in, are, is,
# Nearest to d: b, one, writer, nine, eight, laureate, composer, politician,
# Nearest to first: the, on, was, in, a, by, second, with,
# Nearest to over: total, years, under, zero, five, four, two, three,
# Nearest to war: forces, army, during, battle, troops, invasion, allied, attack,
# Nearest to to: but, a, the, it, an, in, their, and,
# Nearest to proposed: general, responsible, principle, state, theoretical, membership, proposal, government,
# Nearest to troops: forces, war, army, armies, soldiers, battle, allied, armed,
# Nearest to smith: economist, author, cooke, susskind, john, book, greg, annette,
# Nearest to quite: very, well, some, similar, these, more, though, somewhat,
# Nearest to woman: children, her, she, birth, mother, women, married, father,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, d, scientist, american,
# Nearest to governor: appointed, president, general, former, states, legislature, advice, senate,
# Nearest to construction: building, city, built, industries, capital, industrial, constructed, transport,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 4.0259 0.1175 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 4.0423 0.1171 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.9331 0.1166 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.9959 0.1120 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.9678 0.1160 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.9505 0.1156 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 4.0005 0.1167 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 4.0217 0.1141 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.9969 0.1129 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 4.0100 0.1122 sec/batch
# Nearest to or: be, is, can, are, such, usually, not, any,
# Nearest to th: rd, century, nd, st, central, east, lost, west,
# Nearest to all: there, are, the, a, only, every, is, number,
# Nearest to d: b, one, nine, writer, eight, laureate, seven, composer,
# Nearest to first: the, was, after, in, on, by, third, with,
# Nearest to over: years, total, under, there, the, five, four, every,
# Nearest to war: forces, army, troops, soviet, battle, during, allied, invasion,
# ...
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8645 0.1170 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7887 0.1157 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8445 0.1148 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7749 0.1158 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8204 0.1168 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8274 0.1150 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8383 0.1153 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8098 0.1148 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8507 0.1170 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8732 0.1144 sec/batch
# Nearest to or: is, are, be, any, a, can, for, usually,
# Nearest to th: century, rd, nd, st, centuries, central, one, east,
# Nearest to all: in, are, there, the, and, is, for, only,
# Nearest to d: b, one, laureate, american, writer, politician, poet, nine,
# Nearest to first: was, the, after, by, in, later, and, on,
# Nearest to over: years, under, two, five, in, three, the, seven,
# Nearest to war: battle, allied, forces, wwii, troops, soviet, allies, casualties,
# Nearest to to: and, in, a, that, an, for, as, the,
# Nearest to proposed: model, explain, proposal, explanations, theories, theoretical, rejected, implications,
# Nearest to troops: forces, army, soldiers, withdraw, war, allies, armies, retreated,
# Nearest to smith: john, economist, joseph, thomas, bill, latter, cooke, peter,
# Nearest to quite: much, very, more, exist, few, somewhat, relatively, tremendous,
# Nearest to woman: children, female, birth, her, she, women, mother, fertility,
# Nearest to nobel: prize, laureate, recipient, physicist, american, physiology, politician, peace,
# Nearest to governor: appointed, advice, legislature, president, senate, representatives, lieutenant, elected,
# Nearest to construction: building, built, constructed, industrial, opened, industries, constructing, buildings,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8193 0.1184 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8696 0.1177 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8672 0.1163 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8928 0.1112 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8521 0.1076 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8393 0.1096 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8601 0.1158 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8235 0.1157 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8576 0.1170 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8636 0.1122 sec/batch
# Nearest to or: is, a, are, be, as, generally, for, both,
# Nearest to th: century, rd, nd, centuries, st, central, lost, one,
# Nearest to all: there, for, and, called, the, are, only, in,
# Nearest to d: b, one, laureate, writer, american, composer, politician, c,
# Nearest to first: was, the, after, later, in, by, of, on,
# Nearest to over: years, three, two, five, one, under, four, seven,
# Nearest to war: battle, allied, invasion, wwii, defeat, allies, troops, decisive,
# Nearest to to: and, the, in, that, of, this, a, for,
# Nearest to proposed: proposal, model, rejected, would, was, general, proposing, that,
# Nearest to troops: army, soldiers, forces, war, allies, withdraw, armies, battle,
# Nearest to smith: john, economist, joseph, thomas, cooke, wilson, peter, evagrius,
# Nearest to quite: more, much, very, few, clues, somewhat, tremendous, interesting,
# Nearest to woman: female, children, birth, she, her, lady, fertility, husbands,
# Nearest to nobel: prize, laureate, recipient, physicist, physiology, american, peace, politician,
# Nearest to governor: advice, appointed, legislature, president, senate, lieutenant, representatives, executive,
# Nearest to construction: constructed, building, built, opened, constructing, buildings, industrial, industries,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8566 0.1181 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8321 0.1150 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8438 0.1161 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8081 0.1162 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8977 0.1148 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8574 0.1153 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9678 0.1135 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8971 0.1163 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8992 0.1155 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8124 0.1160 sec/batch
# Nearest to or: is, are, a, be, generally, any, usually, as,
# Nearest to th: century, rd, nd, centuries, one, st, central, lost,
# Nearest to all: are, in, there, called, the, for, only, of,
# Nearest to d: b, composer, laureate, writer, american, one, politician, eight,
# Nearest to first: after, was, later, the, in, by, had, of,
# Nearest to over: years, three, seven, five, two, under, one, four,
# Nearest to war: allied, battle, invasion, wwii, fought, warfare, forces, occupation,
# Nearest to to: and, in, a, the, that, of, from, on,
# Nearest to proposed: proposal, model, would, proposing, rejected, although, general, was,
# Nearest to troops: army, forces, withdraw, soldiers, allies, war, invade, retreated,
# Nearest to smith: economist, joseph, john, latter, wilson, cooke, thomas, evagrius,
# Nearest to quite: very, much, somewhat, clues, few, more, can, influence,
# Nearest to woman: children, female, birth, her, she, husband, fertility, lady,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, american, peace, politician,
# Nearest to governor: advice, appointed, president, legislature, senate, former, lieutenant, representatives,
# Nearest to construction: constructed, building, built, industrial, opened, industries, buildings, bridges,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7686 0.1165 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8480 0.1160 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7748 0.1163 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8787 0.1166 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8126 0.1164 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8198 0.1145 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8682 0.0674 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8194 0.1173 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8239 0.1162 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8259 0.1173 sec/batch
# Nearest to or: is, are, a, as, such, can, typically, both,
# Nearest to th: century, rd, nd, st, centuries, central, east, period,
# Nearest to all: in, the, there, for, called, is, a, are,
# Nearest to d: b, one, composer, american, writer, eight, nine, laureate,
# Nearest to first: the, after, was, later, in, by, on, and,
# Nearest to over: years, under, zero, three, two, five, there, seven,
# Nearest to war: battle, invasion, wwii, allied, forces, civil, fought, casualties,
# Nearest to to: and, in, that, a, an, the, with, not,
# Nearest to proposed: proposal, implications, would, model, rejected, explain, proposing, particle,
# Nearest to troops: army, forces, soldiers, withdraw, war, surrender, armed, allies,
# Nearest to smith: economist, joseph, john, latter, cooke, wilson, evagrius, thomas,
# Nearest to quite: very, much, more, few, somewhat, quickly, talent, well,
# Nearest to woman: children, birth, female, her, she, husband, lady, women,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, peace, american, politician,
# Nearest to governor: advice, president, appointed, legislature, senate, lieutenant, former, elected,
# Nearest to construction: building, constructed, built, industrial, industries, opened, constructing, buildings,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8087 0.1169 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8166 0.1098 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8044 0.1113 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8088 0.1167 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8387 0.1155 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7995 0.1164 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8715 0.1163 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7525 0.1138 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7757 0.1163 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7623 0.1163 sec/batch
# Nearest to or: are, is, a, such, can, usually, be, for,
# Nearest to th: century, rd, nd, centuries, st, east, one, lost,
# Nearest to all: for, there, the, a, of, are, only, every,
# Nearest to d: b, one, c, laureate, n, composer, four, writer,
# Nearest to first: the, after, was, in, by, later, and, with,
# Nearest to over: years, under, one, three, two, zero, seven, four,
# Nearest to war: battle, invasion, forces, wwii, allied, warfare, fought, casualties,
# Nearest to to: a, and, that, the, in, an, of, from,
# Nearest to proposed: explain, implications, model, proposal, rejected, would, that, although,
# Nearest to troops: army, soldiers, forces, withdraw, war, retreat, armies, armed,
# Nearest to smith: joseph, economist, latter, john, thomas, book, peter, revelation,
# Nearest to quite: very, much, few, more, somewhat, can, tremendous, gemination,
# Nearest to woman: female, her, children, birth, she, women, husband, mother,
# Nearest to nobel: prize, laureate, recipient, physicist, physiology, peace, american, winners,
# Nearest to governor: appointed, advice, legislature, president, senate, elected, lieutenant, governors,
# Nearest to construction: building, built, constructed, opened, industrial, constructing, buildings, industries,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7224 0.1165 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7816 0.1160 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8214 0.1165 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7933 0.1164 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7946 0.1119 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8904 0.1142 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8390 0.1163 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7928 0.1151 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7923 0.1164 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8240 0.1146 sec/batch
# Nearest to or: is, a, are, be, usually, as, for, any,
# Nearest to th: century, rd, nd, st, centuries, east, lost, one,
# Nearest to all: there, for, the, called, a, is, are, only,
# Nearest to d: b, one, laureate, american, c, composer, four, seven,
# Nearest to first: the, was, after, in, later, and, by, as,
# Nearest to over: years, three, two, one, under, the, zero, there,
# Nearest to war: battle, wwii, allied, invasion, fought, civil, forces, casualties,
# Nearest to to: and, a, the, as, that, in, this, for,
# Nearest to proposed: implications, proposal, proposing, rejected, would, theories, model, explain,
# Nearest to troops: army, forces, soldiers, withdraw, retreated, retreat, war, allies,
# Nearest to smith: joseph, economist, john, latter, thomas, cooke, peter, wilson,
# Nearest to quite: much, very, more, gemination, tremendous, few, little, pockets,
# Nearest to woman: her, female, children, she, birth, husband, husbands, women,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, peace, american, winners,
# Nearest to governor: appointed, advice, legislature, senate, president, lieutenant, governors, elected,
# Nearest to construction: building, built, constructed, industrial, constructing, opened, buildings, industries,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8628 0.1178 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8039 0.1148 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7830 0.1160 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8310 0.1169 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8517 0.1160 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8319 0.1133 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8155 0.1148 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8249 0.1157 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7903 0.1122 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7911 0.1112 sec/batch
# Nearest to or: a, is, are, be, as, usually, and, such,
# Nearest to th: century, rd, nd, centuries, central, lost, st, east,
# Nearest to all: there, are, for, called, and, in, is, the,
# Nearest to d: b, one, c, composer, four, seven, laureate, eight,
# Nearest to first: was, after, the, later, on, in, by, and,
# Nearest to over: two, three, one, seven, five, under, years, the,
# Nearest to war: battle, allied, wwii, fought, troops, defeat, occupation, invasion,
# Nearest to to: and, the, in, that, a, as, not, an,
# Nearest to proposed: proposal, would, implications, rejected, although, that, proposing, general,
# Nearest to troops: army, forces, soldiers, war, withdraw, allies, armed, surrender,
# Nearest to smith: economist, joseph, john, thomas, wilson, cooke, peter, nauvoo,
# Nearest to quite: very, much, clues, more, another, few, can, however,
# Nearest to woman: female, her, children, she, birth, husband, fertility, husbands,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, peace, winners, prizes,
# Nearest to governor: appointed, advice, senate, legislature, lieutenant, governors, president, commander,
# Nearest to construction: building, built, constructed, constructing, opened, industrial, buildings, bridges,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8411 0.1155 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8327 0.1144 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9110 0.1155 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8962 0.1169 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8551 0.1154 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8024 0.1165 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7170 0.1119 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8070 0.1158 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7091 0.1163 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8261 0.1157 sec/batch
# Nearest to or: is, are, a, be, such, usually, can, any,
# Nearest to th: century, rd, nd, centuries, central, east, st, lost,
# Nearest to all: there, are, is, for, not, the, this, a,
# Nearest to d: b, one, american, writer, composer, seven, nine, politician,
# Nearest to first: after, the, was, by, later, and, on, with,
# Nearest to over: years, two, there, three, under, zero, the, five,
# Nearest to war: battle, allied, wwii, civil, defeat, invasion, liberated, fought,
# Nearest to to: a, and, the, in, for, an, with, as,
# Nearest to proposed: proposal, would, rejected, implications, proposing, although, accepted, general,
# Nearest to troops: army, forces, withdraw, soldiers, war, surrender, armed, retreated,
# Nearest to smith: joseph, john, economist, peter, latter, wilson, thomas, cooke,
# Nearest to quite: quickly, very, another, much, few, can, however, clues,
# Nearest to woman: children, female, birth, her, she, fertility, husband, women,
# Nearest to nobel: prize, laureate, recipient, physiology, physicist, american, peace, winners,
# Nearest to governor: appointed, advice, lieutenant, legislature, senate, governors, president, senators,
# Nearest to construction: building, constructed, built, constructing, industrial, industries, opened, buildings,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8235 0.1174 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7951 0.1148 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
